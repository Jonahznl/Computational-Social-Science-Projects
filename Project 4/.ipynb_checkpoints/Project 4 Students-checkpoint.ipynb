# %% [markdown]
# # [Computational Social Science] Project 4: Unsupervised Learning
#
# **Enter your Name:** Jonah Lin
#
# *Semester:* Fall 2023

# %% [markdown]
# ## Data Description and Preprocessing
#
# For this project, you will explore data from the [National Health and Nutrition Examination Survey](https://www.kaggle.com/cdc/national-health-and-nutrition-examination-survey?select=questionnaire.csv). NHANES is a unique study that combines survey methodology with in-person medical examinations to create a dataset with demographic information, health indicators, and health outcomes.

# %% [markdown]
# We start by importing the data and doing some preliminary preprocessing for you. We import some libraries that will be helpful as well. 'SEQN' is the ID number for each respondent, and 'HSD010' will be our target outcome. [HSD010](https://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/HSQ_H.htm#HSD010) asks for the respondent's self reported health condition, which can range from "excellent" to "poor."

# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
sns.set_style("darkgrid")
from sklearn.model_selection import train_test_split

# %%
# Load nhanes data
nhanes = pd.read_csv('nhanes.csv')
# Get the ID numbers for each observation (seqn)
seqn = nhanes['SEQN']
# Get the target, "self-reported health condition," HSD010
hsd010 = nhanes['HSD010']
# Drop SEQN from the dataframe and then apply the standard scaler
nhanes = nhanes.drop(['SEQN', 'HSD010'], axis = 1)
nhanes_scaled = pd.DataFrame(StandardScaler().fit_transform(nhanes),
                             columns = nhanes.columns)
# Add the ID and target back in
nhanes_scaled['SEQN'] = seqn
nhanes_scaled['HSD010'] = hsd010
nhanes_scaled = nhanes_scaled.set_index('SEQN')
nhanes_scaled.head()
# Out:
#        DR1DRSTZ  DR1EXMER  DRABF    DRDINT   DR1DBIH    DR1DAY   DR1LANG  \
# SEQN
# 73568       0.0  2.034312    0.0  0.324834 -0.393906  1.085853 -0.194202
# 73576       0.0  0.261930    0.0 -3.078499  0.568251  0.634362 -0.194202
# 73579       0.0  0.728346    0.0  0.324834  1.530407 -1.623092 -0.194202
# 73581       0.0 -0.857470    0.0  0.324834  0.480782  1.085853 -0.194202
# 73584       0.0  0.495138    0.0  0.324834  0.305844 -1.623092 -0.194202
#
#        DR1MNRSP  DR1HELPD   DBQ095Z  ...    OHQ770    OHQ845   PAAQUEX  \
# SEQN                                 ...
# 73568 -0.057306  0.128246 -0.189513  ...  0.383802 -0.646584 -0.484200
# 73576 -0.057306  0.128246  0.080373  ...  0.383802 -1.539259 -0.484200
# 73579 -0.057306  0.128246 -0.189513  ...  0.383802 -1.539259  2.065262
# 73581 -0.057306  0.128246  0.080373  ...  0.383802 -0.646584 -0.484200
# 73584 -0.057306  0.128246  0.080373  ... -2.605509  0.246091  2.065262
#
#          SMQ860  SMQ870    SMQ872    SMQ874    SMQ878  SMAQUEX.x  HSD010
# SEQN
# 73568  1.125008     0.0 -2.081666  1.087115  1.463404   0.612440       1
# 73576  1.125008     0.0 -2.081666  1.087115 -0.683338  -1.632812       1
# 73579 -0.888883     0.0  0.480384 -0.919866 -0.683338  -1.632812       2
# 73581  1.125008     0.0  0.480384 -0.919866 -0.683338   0.612440       2
# 73584  1.125008     0.0  0.480384 -0.919866  1.463404  -1.632812       3
#
# [5 rows x 242 columns]

# %%
list(nhanes_scaled.columns).index('INDFMPIR'), list(nhanes_scaled.columns).index('BMXBMI')
# Out:
# (175, 76)

# %%
nhanes_scaled.shape
# Out:
# (2064, 242)

# %% [markdown]
# ## Plots

# %% [markdown]
# Let's take a look at the data. Below we visualize boxplots of family income to federal poverty line ratio ('INDFMPIR') and self-reported health condition. Notice how there are some clear patterns (the lower the ratio, the lower reported health condition), but it's not a perfect separation. We have 240+ features in our dataset, and we likely have several features in our dataset that highly correlate with our family income-poverty line ratio measure - PCA will help us simplify these.

# %%
# Create a binary version of hsd010 where 1-3 are "good" and 4-5 are "poor"
nhanes_scaled['HSD010_binary'] = hsd010_binary = nhanes_scaled['HSD010'].replace(
    [1, 2, 3, 4, 5], ['good', 'good', 'good', 'poor', 'poor']) 
# Recode the original hsd010 with the string labels
nhanes_scaled['HSD010'] = nhanes_scaled['HSD010'].replace(
    [1, 2, 3, 4, 5], ['excellent', 'very good', 'good', 'fair', 'poor'])
# Boxplot of hsd010
ax = sns.boxplot(x = 'HSD010', y = 'INDFMPIR', data = nhanes_scaled)
ax.set(xlabel = "Self Reported Health Condition",
      ylabel = "Family Income to Poverty Line Ratio")
ax.set_title("Boxplot of Family Income to Poverty Line Ratio by Self-Reported Health Status")
plt.show()

# %%
# Boxplot of hsd010_binary
ax = sns.boxplot(x = 'HSD010_binary', y = 'INDFMPIR', data = nhanes_scaled)
ax.set(xlabel = "Self Reported Health Condition",
      ylabel = "Family Income to Poverty Line Ratio")
ax.set_title("Boxplot of Family Income to Poverty Line Ratio by Binary Self-Reported Health Status")
plt.show()

# %% [markdown]
# Family income also is not necessarily well correlated with measured health outcomes. See below where we look at the relationship between Body Mass Index (BMI) and the family income-poverty line ratio, and shade points by self-reported health condition. It's hard to find a clear pattern - this is where clustering may come in handy.

# %%
ax = sns.scatterplot(x = "INDFMPIR", y = "BMXBMI", hue = "HSD010", palette = "tab10", data = nhanes_scaled)
ax.set(xlabel = "Income to Poverty Line Ratio",
      ylabel = "Body Mass Index")
ax.set_title("BMI v. Income-Poverty Ratio")
plt.show()

# %% [markdown]
# Before we move to working on unsupervised methods, we'll drop our target variables again:

# %%
nhanes_scaled = nhanes_scaled.drop(['HSD010', 'HSD010_binary'], axis = 1)

# nhanes_scaled['HSD010']

# %% [markdown]
# ## Principal Component Analysis

# %% [markdown]
# Conduct a Principal Component Analysis (PCA) of the nhanes data. The data has already been prepared for you, so you can work directly on nhanes_scaled. Be sure to do the following:
#
# - Choose the number of components and provide 1-2 sentences about your choice of the number of components.
# - Plot a barplot of the variation explained by each component. *Hint*: look at the attributes associated with your model.
# - Choose how many components you will use to fit a supervised learning model and provide 1-2 sentences to explain that choice.
# - Plot a 2D scatterplot of the first two components and provide 1-2 sentences analyzing the plot.

# %% [markdown]
# ### Train PCA and Discuss Number of Components

# %% [markdown]
# **Answer:**
# \
# Because the variance explained by each component is not clear at this point, I want to choose as many components as possible. But to plot all the chosen components, it shouldn't be larger than 100 or 200. So, I choose 80.

# %%
## Your Answer Here


X = StandardScaler().fit_transform(nhanes_scaled.values) 


pca_all = PCA() # notice we do not specify the number of components if we want to keep them all
principalComponents_nhanes = pca_all.fit_transform(X)

# %%
pca_80 = PCA(n_components=80) # notice we do not specify the number of components if we want to keep them all
PCA_80_components = pca_80.fit_transform(X)

# %%
sum(pca_80.explained_variance_ratio_) / sum(pca_all.explained_variance_ratio_)
# Out:
# 0.7762520420037851

# %% [markdown]
# ### Barplot of Components

# %%
## Your Answer Here

PC_values = np.arange(pca_80.n_components_) + 1

plt.bar(PC_values, pca_80.explained_variance_ratio_)
plt.xlabel('Principal Component')
plt.ylabel('Variance Explained')
plt.show()

# %% [markdown]
# ### How many components will you use to fit a supervised learning model?

# %% [markdown]
# **Answer:**
# \
# I choose 40 components for supervised learning later. As shown below, 40 components can explain almost 60% of all variance of the dataset.

# %%
## Your Answer Here


pca_40 = PCA(n_components=40) # notice we do not specify the number of components if we want to keep them all
PCA_40_components = pca_40.fit_transform(X)

sum(pca_40.explained_variance_ratio_)
# Out:
# 0.5952951423250376

# %%
PCA_40_components
# Out:
# array([[ 9.52780636, -0.81622323, -1.86687175, ...,  0.47449391,
#          0.17129698,  0.8820415 ],
#        [-5.83831555, -3.69256594,  3.80545242, ...,  1.92129929,
#         -2.10214451,  3.98185831],
#        [-0.71945799, -2.57319868,  0.90793067, ...,  0.85904115,
#          1.28031684,  0.94713843],
#        ...,
#        [ 1.13025207, -0.97043969,  3.41555137, ..., -0.05058064,
#          1.65423966, -0.80380849],
#        [ 7.14509619, -0.3767367 ,  1.7535894 , ...,  2.02846675,
#          0.10908035,  0.43654942],
#        [ 0.05086898, -0.96730601, -4.44771862, ...,  0.89945598,
#         -0.80448832, -0.68620124]])

# %%
PCA_40_components.shape
# Out:
# (2064, 40)

# %%
X.shape
# Out:
# (2064, 241)

# %% [markdown]
# ### 2D Scatterplot of the first two components

# %%
## Your Answer Here


pca_df = pd.DataFrame(data = PCA_40_components[:,:2], 
                      columns = ['principal component 1', 
                                 'principal component 2'])

# figure settings
plt.figure()
plt.figure(figsize=(10,10))
plt.xticks(fontsize=12)
plt.yticks(fontsize=14)
plt.xlabel('Principal Component - 1',fontsize=20)
plt.ylabel('Principal Component - 2',fontsize=20)
targets = [1, 2, 3, 4, 5]
colors = ['blue', 'orange', 'green', 'red', 'purple']

# loop over targets and colors to create scatterplot
for target, color in zip(targets,colors):
    indicesToKeep = hsd010 == target
    plt.scatter(pca_df.loc[indicesToKeep, 'principal component 1'], 
                pca_df.loc[indicesToKeep, 'principal component 2'], c = color, s = 50)

# show figure
plt.legend(targets,prop={'size': 15})
plt.show();

# %% [markdown]
# **Answer:**
# \
# From the figure, it is hard to tell a distribution pattern of the results (1=excellent, 2=very good...). It means the first two components do not catch enough variance of the data to show a pattern.

# %% [markdown]
# ## K-Means

# %% [markdown]
# - Choose a clustering algorithm and explain it in 1-2 sentences.
# - Cluster the nhanes data. Detail any choice you need to make with regards to number of clusters, and how you arrived at that choice. For instance, you might use the [elbow method](https://en.wikipedia.org/wiki/Elbow_method_(clustering)) if you choose k-means.
# - Plot your clusters on top of BMI v. Income Poverty Ratio Plot. Describe what you see in 1-2 sentences.
# - Retrain the clustering algorithm, but this time use your PCA results instead of the original dataframe. Plot the clusters on top of the 2D PCA scatterplot from the previous step. Describe your results in 1-2 sentences.

# %% [markdown]
# ### Choose a Clustering Algorithm

# %%
## Your Answer Here

# %% [markdown]
# **Answer:**
# \
# K-means.
# There is no obvious pattern of the distribution that makes any algorithms a better fit. With K-means, the number of clusters can be adjusted to find a (near) optimal cluster count that reduces the variance within clusters while not making too many clusters.

# %% [markdown]
# ### Cluster nhanes

# %%
## Your Answer Here

# %%
from sklearn.metrics import silhouette_samples, silhouette_score

range_n_clusters = list(range(2,20))
silho_score_list = []
distorsions = []

for n_clusters in range_n_clusters:

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, n_init="auto", random_state=10).fit(X)
    cluster_labels = clusterer.predict(X)
    
    distorsions.append(clusterer.inertia_)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(X, cluster_labels)
    silho_score_list.append(silhouette_avg)

fig, ax1 = plt.subplots()
line1, = ax1.plot(range_n_clusters, distorsions, 'go', label="elbow")
ax1.tick_params(axis='y', labelcolor='tab:green')

ax2 = ax1.twinx()
line2, = ax2.plot(range_n_clusters, silho_score_list, 'bx', label="silho_score")
ax2.tick_params(axis='y', labelcolor='tab:blue')

lines = [line1, line2]
labels = [line.get_label() for line in lines]

ax1.legend(lines, labels)

plt.show()

# %% [markdown]
# **Answer:**
# \
# The there is an elblow point at cluster_number=5, while the silhouette score remains relatively high. Plus, the number of clusters to be predicted for hsd010 is 5.

# %%
kmeans = KMeans(n_clusters=5, random_state=0).fit(X)
# Out:
# /Users/zhounanlin/anaconda3/envs/anlp/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %% [markdown]
# ### Plot your clusters on top of the BMI v. Income Poverty Ratio Plot

# %%
## Your Answer Here

# %%
X.shape
# Out:
# (2064, 241)

# %%
X[kmeans.labels_==0,:].shape
# Out:
# (150, 241)

# %%
X[kmeans.labels_==0,:][:2,:].shape
# Out:
# (2, 241)

# %%
# kmeans.cluster_centers_[:2,:]

# %%
X[kmeans.labels_==0,:].shape
# Out:
# (150, 241)

# %%
# X[kmeans.labels_==0,:][:, [175, 76]].T

# %%
# figure settings
fig = plt.figure()
ax1 = fig.add_subplot(111)

# plot
ax1.scatter(*(X[kmeans.labels_==0,:][:, [175, 76]].T), s=50, c='r', label='Cluster 0')
ax1.scatter(*(X[kmeans.labels_==1,:][:, [175, 76]].T), s=50, c='b', label='Cluster 1')
ax1.scatter(*(X[kmeans.labels_==2,:][:, [175, 76]].T), s=50, c='g', label='Cluster 2')
ax1.scatter(*(X[kmeans.labels_==3,:][:, [175, 76]].T), s=50, c='orange', label='Cluster 3')
ax1.scatter(*(X[kmeans.labels_==4,:][:, [175, 76]].T), s=50, c='purple', label='Cluster 4')
ax1.scatter(*kmeans.cluster_centers_[:, [175, 76]].T, s=50, marker='+', c='black', label='cluster centers')
plt.legend(loc='upper left')
plt.xlabel('feature0')
plt.ylabel('feature1')
plt.show()

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# **Answer:**
# \
# The resulting clusters do show some patterns. The blue cluster seems to be centered around the bottom right, while the purple cluster seems to be centered around bottom left. However, it not clear at this point which cluster corresponds to which HSD010 (self reported health condition).

# %% [markdown]
# ### Retrain the clustering algorithm on PCA components and plot clusters on your 2D scatter

# %%
## Your Answer Here

# %%
kmeans_2 = KMeans(n_clusters=5, random_state=0).fit(PCA_40_components)
# Out:
# /Users/zhounanlin/anaconda3/envs/anlp/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
PCA_40_components[kmeans_2.labels_==4,:].shape
# Out:
# (711, 40)

# %%
kmeans_2.cluster_centers_[:, :2].T
# Out:
# array([[-2.66594285, -2.17214747, -4.23396481,  7.45966301, -0.22465103],
#        [-2.62853748,  1.04721726, 12.18948474,  0.65310601, -2.02656755]])

# %%
# figure settings
fig2 = plt.figure()
ax2 = fig2.add_subplot(111)

# plot
ax2.scatter(*(PCA_40_components[kmeans_2.labels_==0,:][:, :2].T), s=50, c='r', label='Cluster 0')
ax2.scatter(*(PCA_40_components[kmeans_2.labels_==1,:][:, :2].T), s=50, c='b', label='Cluster 1')
ax2.scatter(*(PCA_40_components[kmeans_2.labels_==2,:][:, :2].T), s=50, c='g', label='Cluster 2')
ax2.scatter(*(PCA_40_components[kmeans_2.labels_==3,:][:, :2].T), s=50, c='orange', label='Cluster 3')
ax2.scatter(*(PCA_40_components[kmeans_2.labels_==4,:][:, :2].T), s=50, c='purple', label='Cluster 4')
ax2.scatter(*kmeans_2.cluster_centers_[:, :2].T, s=50, marker='+', c='black', label='cluster centers')
plt.legend(loc='upper left')
plt.xlabel('feature0')
plt.ylabel('feature1')
plt.show()

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# **Answer:**
# \
# A clear distribution pattern is visible in the figure above.
# \
# However, comparing this figure to the figure in "2D Scatterplot of the first two components" of PCA analysis section, the five clusters achieved from the kmeans clustering of PCA components is not very accurate.

# %% [markdown]
# ## Neural Network

# %% [markdown]
# Now we are ready to predict! Do the following:
#
# - Choose either HSD010 or HSD010\_binary as your target outcome.
# - Train a neural network using the original features. Much of the code to train a basic neural net has been set up for you, but you will need to fill in a couple of missing pieces.
# - Train a neural network using only your PCA components as features.
# - Train a neural network using your PCA components and the predicted class membership from your clustering algorithm as features.
# - Compare and contrast how well each algorithm did. Which featurization technique would you pick and why?

# %% [markdown]
# Below we provide a template for training a neural network. Use this template for training on the original features, on the PCA components, and the PCA components + the predicted classes from your clusters.

# %% [markdown]
# ### Neural Network on Original Features

# %%
## Your Answer Here

# %%
# partition data
# -----------
y = hsd010 # either hsd010 or hsd010_binary, may need to convert to numeric if it isn't already 
X_nn = X # drop out any columns that aren't features

X_train, X_test, y_train, y_test = train_test_split(X_nn, 
                                                    y, 
                                                    test_size = .25, 
                                                    random_state = 10)


# keras.utils.to_categorical
# starts index from 0
# so, reduce y_train and y_test by 1

y_train -= 1
y_test -= 1

# %%
# load libraries
# -----------
import keras
from keras.utils import to_categorical

num_classes = 5
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
num_classes = y_test.shape[1]

# %%
num_classes
# Out:
# 5

# %%
X_train.shape
# Out:
# (1548, 241)

# %%
# %%time

# create neural network model
# -----------
model = Sequential()

model.add(Dense(X_train.shape[1], input_dim=X_train.shape[1], kernel_initializer='normal', activation='relu'))

model.add(Dense(num_classes, kernel_initializer='normal', activation='softmax'))

## Add any additional layers you wish here

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=20, batch_size=200, verbose=2)
# Out:
# Epoch 1/20
# 8/8 - 0s - loss: 1.5079 - accuracy: 0.3191 - val_loss: 1.3296 - val_accuracy: 0.4399 - 177ms/epoch - 22ms/step
# Epoch 2/20
# 8/8 - 0s - loss: 1.2234 - accuracy: 0.4922 - val_loss: 1.2583 - val_accuracy: 0.4380 - 17ms/epoch - 2ms/step
# Epoch 3/20
# 8/8 - 0s - loss: 1.1255 - accuracy: 0.5349 - val_loss: 1.2271 - val_accuracy: 0.4399 - 19ms/epoch - 2ms/step
# Epoch 4/20
# 8/8 - 0s - loss: 1.0467 - accuracy: 0.5782 - val_loss: 1.2053 - val_accuracy: 0.4535 - 21ms/epoch - 3ms/step
# Epoch 5/20
# 8/8 - 0s - loss: 0.9829 - accuracy: 0.6130 - val_loss: 1.1975 - val_accuracy: 0.4535 - 20ms/epoch - 3ms/step
# Epoch 6/20
# 8/8 - 0s - loss: 0.9272 - accuracy: 0.6350 - val_loss: 1.1946 - val_accuracy: 0.4748 - 25ms/epoch - 3ms/step
# Epoch 7/20
# 8/8 - 0s - loss: 0.8758 - accuracy: 0.6583 - val_loss: 1.1931 - val_accuracy: 0.4709 - 25ms/epoch - 3ms/step
# Epoch 8/20
# 8/8 - 0s - loss: 0.8292 - accuracy: 0.6751 - val_loss: 1.1946 - val_accuracy: 0.4748 - 22ms/epoch - 3ms/step
# Epoch 9/20
# 8/8 - 0s - loss: 0.7844 - accuracy: 0.7158 - val_loss: 1.1976 - val_accuracy: 0.4671 - 24ms/epoch - 3ms/step
# Epoch 10/20
# 8/8 - 0s - loss: 0.7400 - accuracy: 0.7455 - val_loss: 1.2003 - val_accuracy: 0.4748 - 19ms/epoch - 2ms/step
# Epoch 11/20
# 8/8 - 0s - loss: 0.6956 - accuracy: 0.7700 - val_loss: 1.2099 - val_accuracy: 0.4806 - 16ms/epoch - 2ms/step
# Epoch 12/20
# 8/8 - 0s - loss: 0.6561 - accuracy: 0.7913 - val_loss: 1.2159 - val_accuracy: 0.4729 - 16ms/epoch - 2ms/step
# Epoch 13/20
# 8/8 - 0s - loss: 0.6157 - accuracy: 0.8133 - val_loss: 1.2284 - val_accuracy: 0.4806 - 16ms/epoch - 2ms/step
# Epoch 14/20
# 8/8 - 0s - loss: 0.5766 - accuracy: 0.8307 - val_loss: 1.2374 - val_accuracy: 0.4709 - 16ms/epoch - 2ms/step
# Epoch 15/20
# 8/8 - 0s - loss: 0.5415 - accuracy: 0.8488 - val_loss: 1.2508 - val_accuracy: 0.4709 - 16ms/epoch - 2ms/step
# Epoch 16/20
# 8/8 - 0s - loss: 0.5044 - accuracy: 0.8643 - val_loss: 1.2633 - val_accuracy: 0.4632 - 16ms/epoch - 2ms/step
# Epoch 17/20
# 8/8 - 0s - loss: 0.4717 - accuracy: 0.8863 - val_loss: 1.2805 - val_accuracy: 0.4709 - 16ms/epoch - 2ms/step
# Epoch 18/20
# 8/8 - 0s - loss: 0.4388 - accuracy: 0.8979 - val_loss: 1.2964 - val_accuracy: 0.4632 - 16ms/epoch - 2ms/step
# Epoch 19/20
# 8/8 - 0s - loss: 0.4068 - accuracy: 0.9141 - val_loss: 1.3133 - val_accuracy: 0.4632 - 15ms/epoch - 2ms/step
# Epoch 20/20
# 8/8 - 0s - loss: 0.3784 - accuracy: 0.9289 - val_loss: 1.3245 - val_accuracy: 0.4671 - 16ms/epoch - 2ms/step
# CPU times: user 742 ms, sys: 122 ms, total: 864 ms
# Wall time: 609 ms

# %% [markdown]
# ### Neural Network on Principal Components

# %%
## Your Answer Here

# %%
# partition data
# -----------
y = hsd010 # either hsd010 or hsd010_binary, may need to convert to numeric if it isn't already 
X_nn = PCA_40_components # drop out any columns that aren't features

X_train, X_test, y_train, y_test = train_test_split(X_nn, 
                                                    y, 
                                                    test_size = .25, 
                                                    random_state = 10)


# keras.utils.to_categorical
# starts index from 0
# so, reduce y_train and y_test by 1

y_train -= 1
y_test -= 1

# %%
# load libraries
# -----------
import keras
from keras.utils import to_categorical

num_classes = 5
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
num_classes = y_test.shape[1]

# %%
num_classes
# Out:
# 5

# %%
X_train.shape
# Out:
# (1548, 40)

# %%
# %%time

# create neural network model
# -----------
model = Sequential()

model.add(Dense(X_train.shape[1], input_dim=X_train.shape[1], kernel_initializer='normal', activation='relu'))

model.add(Dense(num_classes, kernel_initializer='normal', activation='softmax'))

## Add any additional layers you wish here

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=40, batch_size=200, verbose=2)
# Out:
# Epoch 1/40
# 8/8 - 0s - loss: 1.6103 - accuracy: 0.2016 - val_loss: 1.5799 - val_accuracy: 0.2829 - 170ms/epoch - 21ms/step
# Epoch 2/40
# 8/8 - 0s - loss: 1.5476 - accuracy: 0.3721 - val_loss: 1.5243 - val_accuracy: 0.3721 - 15ms/epoch - 2ms/step
# Epoch 3/40
# 8/8 - 0s - loss: 1.4922 - accuracy: 0.4432 - val_loss: 1.4764 - val_accuracy: 0.3973 - 15ms/epoch - 2ms/step
# Epoch 4/40
# 8/8 - 0s - loss: 1.4438 - accuracy: 0.4619 - val_loss: 1.4334 - val_accuracy: 0.4109 - 14ms/epoch - 2ms/step
# Epoch 5/40
# 8/8 - 0s - loss: 1.3994 - accuracy: 0.4658 - val_loss: 1.3963 - val_accuracy: 0.4186 - 14ms/epoch - 2ms/step
# Epoch 6/40
# 8/8 - 0s - loss: 1.3599 - accuracy: 0.4696 - val_loss: 1.3649 - val_accuracy: 0.4244 - 14ms/epoch - 2ms/step
# Epoch 7/40
# 8/8 - 0s - loss: 1.3246 - accuracy: 0.4742 - val_loss: 1.3390 - val_accuracy: 0.4302 - 15ms/epoch - 2ms/step
# Epoch 8/40
# 8/8 - 0s - loss: 1.2936 - accuracy: 0.4748 - val_loss: 1.3180 - val_accuracy: 0.4244 - 14ms/epoch - 2ms/step
# Epoch 9/40
# 8/8 - 0s - loss: 1.2669 - accuracy: 0.4897 - val_loss: 1.3010 - val_accuracy: 0.4341 - 15ms/epoch - 2ms/step
# Epoch 10/40
# 8/8 - 0s - loss: 1.2452 - accuracy: 0.4916 - val_loss: 1.2871 - val_accuracy: 0.4264 - 12ms/epoch - 1ms/step
# Epoch 11/40
# 8/8 - 0s - loss: 1.2254 - accuracy: 0.4897 - val_loss: 1.2753 - val_accuracy: 0.4302 - 13ms/epoch - 2ms/step
# Epoch 12/40
# 8/8 - 0s - loss: 1.2092 - accuracy: 0.4968 - val_loss: 1.2653 - val_accuracy: 0.4283 - 14ms/epoch - 2ms/step
# Epoch 13/40
# 8/8 - 0s - loss: 1.1935 - accuracy: 0.5000 - val_loss: 1.2569 - val_accuracy: 0.4264 - 13ms/epoch - 2ms/step
# Epoch 14/40
# 8/8 - 0s - loss: 1.1804 - accuracy: 0.5006 - val_loss: 1.2498 - val_accuracy: 0.4225 - 13ms/epoch - 2ms/step
# Epoch 15/40
# 8/8 - 0s - loss: 1.1686 - accuracy: 0.5065 - val_loss: 1.2438 - val_accuracy: 0.4283 - 13ms/epoch - 2ms/step
# Epoch 16/40
# 8/8 - 0s - loss: 1.1576 - accuracy: 0.5116 - val_loss: 1.2387 - val_accuracy: 0.4302 - 12ms/epoch - 2ms/step
# Epoch 17/40
# 8/8 - 0s - loss: 1.1476 - accuracy: 0.5142 - val_loss: 1.2339 - val_accuracy: 0.4283 - 14ms/epoch - 2ms/step
# Epoch 18/40
# 8/8 - 0s - loss: 1.1384 - accuracy: 0.5168 - val_loss: 1.2299 - val_accuracy: 0.4302 - 16ms/epoch - 2ms/step
# Epoch 19/40
# 8/8 - 0s - loss: 1.1298 - accuracy: 0.5207 - val_loss: 1.2260 - val_accuracy: 0.4341 - 16ms/epoch - 2ms/step
# Epoch 20/40
# 8/8 - 0s - loss: 1.1220 - accuracy: 0.5200 - val_loss: 1.2237 - val_accuracy: 0.4399 - 19ms/epoch - 2ms/step
# Epoch 21/40
# 8/8 - 0s - loss: 1.1141 - accuracy: 0.5226 - val_loss: 1.2216 - val_accuracy: 0.4380 - 17ms/epoch - 2ms/step
# Epoch 22/40
# 8/8 - 0s - loss: 1.1069 - accuracy: 0.5252 - val_loss: 1.2195 - val_accuracy: 0.4399 - 17ms/epoch - 2ms/step
# Epoch 23/40
# 8/8 - 0s - loss: 1.1001 - accuracy: 0.5291 - val_loss: 1.2185 - val_accuracy: 0.4477 - 15ms/epoch - 2ms/step
# Epoch 24/40
# 8/8 - 0s - loss: 1.0934 - accuracy: 0.5317 - val_loss: 1.2174 - val_accuracy: 0.4477 - 12ms/epoch - 1ms/step
# Epoch 25/40
# 8/8 - 0s - loss: 1.0872 - accuracy: 0.5310 - val_loss: 1.2165 - val_accuracy: 0.4516 - 12ms/epoch - 1ms/step
# Epoch 26/40
# 8/8 - 0s - loss: 1.0807 - accuracy: 0.5323 - val_loss: 1.2160 - val_accuracy: 0.4516 - 12ms/epoch - 2ms/step
# Epoch 27/40
# 8/8 - 0s - loss: 1.0745 - accuracy: 0.5336 - val_loss: 1.2168 - val_accuracy: 0.4516 - 13ms/epoch - 2ms/step
# Epoch 28/40
# 8/8 - 0s - loss: 1.0685 - accuracy: 0.5368 - val_loss: 1.2166 - val_accuracy: 0.4496 - 12ms/epoch - 2ms/step
# Epoch 29/40
# 8/8 - 0s - loss: 1.0626 - accuracy: 0.5355 - val_loss: 1.2168 - val_accuracy: 0.4554 - 12ms/epoch - 1ms/step
# Epoch 30/40
# 8/8 - 0s - loss: 1.0568 - accuracy: 0.5401 - val_loss: 1.2177 - val_accuracy: 0.4554 - 12ms/epoch - 2ms/step
# Epoch 31/40
# 8/8 - 0s - loss: 1.0514 - accuracy: 0.5465 - val_loss: 1.2190 - val_accuracy: 0.4516 - 12ms/epoch - 2ms/step
# Epoch 32/40
# 8/8 - 0s - loss: 1.0462 - accuracy: 0.5497 - val_loss: 1.2198 - val_accuracy: 0.4477 - 12ms/epoch - 1ms/step
# Epoch 33/40
# 8/8 - 0s - loss: 1.0413 - accuracy: 0.5556 - val_loss: 1.2213 - val_accuracy: 0.4496 - 12ms/epoch - 2ms/step
# Epoch 34/40
# 8/8 - 0s - loss: 1.0356 - accuracy: 0.5588 - val_loss: 1.2225 - val_accuracy: 0.4477 - 12ms/epoch - 2ms/step
# Epoch 35/40
# 8/8 - 0s - loss: 1.0300 - accuracy: 0.5575 - val_loss: 1.2231 - val_accuracy: 0.4496 - 12ms/epoch - 2ms/step
# Epoch 36/40
# 8/8 - 0s - loss: 1.0249 - accuracy: 0.5698 - val_loss: 1.2251 - val_accuracy: 0.4419 - 12ms/epoch - 2ms/step
# Epoch 37/40
# 8/8 - 0s - loss: 1.0200 - accuracy: 0.5749 - val_loss: 1.2267 - val_accuracy: 0.4419 - 12ms/epoch - 1ms/step
# Epoch 38/40
# 8/8 - 0s - loss: 1.0149 - accuracy: 0.5762 - val_loss: 1.2279 - val_accuracy: 0.4399 - 12ms/epoch - 1ms/step
# Epoch 39/40
# 8/8 - 0s - loss: 1.0098 - accuracy: 0.5795 - val_loss: 1.2298 - val_accuracy: 0.4380 - 12ms/epoch - 2ms/step
# Epoch 40/40
# 8/8 - 0s - loss: 1.0049 - accuracy: 0.5820 - val_loss: 1.2313 - val_accuracy: 0.4457 - 12ms/epoch - 2ms/step
# CPU times: user 781 ms, sys: 124 ms, total: 905 ms
# Wall time: 762 ms

# %% [markdown]
# ### Neural Network on Principal Components + Cluster Membership

# %%
## Your Answer Here

# %%
# np.hstack((PCA_40_components, kmeans_2.labels_.reshape(-1, 1)))

# %%
# partition data
# -----------
y = hsd010 # either hsd010 or hsd010_binary, may need to convert to numeric if it isn't already 
X_nn = np.hstack((PCA_40_components, kmeans_2.labels_.reshape(-1, 1))) # drop out any columns that aren't features

X_train, X_test, y_train, y_test = train_test_split(X_nn, 
                                                    y, 
                                                    test_size = .25, 
                                                    random_state = 10)


# keras.utils.to_categorical
# starts index from 0
# so, reduce y_train and y_test by 1

y_train -= 1
y_test -= 1

# %%
# load libraries
# -----------
import keras
from keras.utils import to_categorical

num_classes = 5
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
num_classes = y_test.shape[1]

# %%
num_classes
# Out:
# 5

# %%
X_train.shape
# Out:
# (1548, 41)

# %%
# %%time

# create neural network model
# -----------
model = Sequential()

model.add(Dense(X_train.shape[1], input_dim=X_train.shape[1], kernel_initializer='normal', activation='relu'))

model.add(Dense(num_classes, kernel_initializer='normal', activation='softmax'))

## Add any additional layers you wish here

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=40, batch_size=200, verbose=2)
# Out:
# Epoch 1/40
# 8/8 - 0s - loss: 1.6150 - accuracy: 0.2255 - val_loss: 1.5767 - val_accuracy: 0.3081 - 169ms/epoch - 21ms/step
# Epoch 2/40
# 8/8 - 0s - loss: 1.5466 - accuracy: 0.3553 - val_loss: 1.5172 - val_accuracy: 0.3682 - 15ms/epoch - 2ms/step
# Epoch 3/40
# 8/8 - 0s - loss: 1.4883 - accuracy: 0.3960 - val_loss: 1.4653 - val_accuracy: 0.3857 - 15ms/epoch - 2ms/step
# Epoch 4/40
# 8/8 - 0s - loss: 1.4366 - accuracy: 0.4289 - val_loss: 1.4197 - val_accuracy: 0.3992 - 16ms/epoch - 2ms/step
# Epoch 5/40
# 8/8 - 0s - loss: 1.3889 - accuracy: 0.4432 - val_loss: 1.3804 - val_accuracy: 0.4167 - 15ms/epoch - 2ms/step
# Epoch 6/40
# 8/8 - 0s - loss: 1.3475 - accuracy: 0.4522 - val_loss: 1.3463 - val_accuracy: 0.4186 - 15ms/epoch - 2ms/step
# Epoch 7/40
# 8/8 - 0s - loss: 1.3115 - accuracy: 0.4677 - val_loss: 1.3178 - val_accuracy: 0.4205 - 15ms/epoch - 2ms/step
# Epoch 8/40
# 8/8 - 0s - loss: 1.2794 - accuracy: 0.4793 - val_loss: 1.2953 - val_accuracy: 0.4457 - 14ms/epoch - 2ms/step
# Epoch 9/40
# 8/8 - 0s - loss: 1.2520 - accuracy: 0.4858 - val_loss: 1.2775 - val_accuracy: 0.4612 - 16ms/epoch - 2ms/step
# Epoch 10/40
# 8/8 - 0s - loss: 1.2280 - accuracy: 0.4897 - val_loss: 1.2623 - val_accuracy: 0.4574 - 12ms/epoch - 2ms/step
# Epoch 11/40
# 8/8 - 0s - loss: 1.2067 - accuracy: 0.4968 - val_loss: 1.2499 - val_accuracy: 0.4496 - 13ms/epoch - 2ms/step
# Epoch 12/40
# 8/8 - 0s - loss: 1.1886 - accuracy: 0.4981 - val_loss: 1.2402 - val_accuracy: 0.4457 - 12ms/epoch - 2ms/step
# Epoch 13/40
# 8/8 - 0s - loss: 1.1731 - accuracy: 0.5019 - val_loss: 1.2322 - val_accuracy: 0.4496 - 14ms/epoch - 2ms/step
# Epoch 14/40
# 8/8 - 0s - loss: 1.1594 - accuracy: 0.5032 - val_loss: 1.2256 - val_accuracy: 0.4496 - 14ms/epoch - 2ms/step
# Epoch 15/40
# 8/8 - 0s - loss: 1.1473 - accuracy: 0.5052 - val_loss: 1.2209 - val_accuracy: 0.4496 - 13ms/epoch - 2ms/step
# Epoch 16/40
# 8/8 - 0s - loss: 1.1371 - accuracy: 0.5084 - val_loss: 1.2167 - val_accuracy: 0.4535 - 15ms/epoch - 2ms/step
# Epoch 17/40
# 8/8 - 0s - loss: 1.1280 - accuracy: 0.5103 - val_loss: 1.2138 - val_accuracy: 0.4593 - 13ms/epoch - 2ms/step
# Epoch 18/40
# 8/8 - 0s - loss: 1.1196 - accuracy: 0.5136 - val_loss: 1.2109 - val_accuracy: 0.4554 - 16ms/epoch - 2ms/step
# Epoch 19/40
# 8/8 - 0s - loss: 1.1116 - accuracy: 0.5123 - val_loss: 1.2080 - val_accuracy: 0.4496 - 16ms/epoch - 2ms/step
# Epoch 20/40
# 8/8 - 0s - loss: 1.1044 - accuracy: 0.5136 - val_loss: 1.2062 - val_accuracy: 0.4574 - 18ms/epoch - 2ms/step
# Epoch 21/40
# 8/8 - 0s - loss: 1.0980 - accuracy: 0.5200 - val_loss: 1.2042 - val_accuracy: 0.4593 - 19ms/epoch - 2ms/step
# Epoch 22/40
# 8/8 - 0s - loss: 1.0914 - accuracy: 0.5258 - val_loss: 1.2037 - val_accuracy: 0.4612 - 19ms/epoch - 2ms/step
# Epoch 23/40
# 8/8 - 0s - loss: 1.0859 - accuracy: 0.5278 - val_loss: 1.2034 - val_accuracy: 0.4612 - 17ms/epoch - 2ms/step
# Epoch 24/40
# 8/8 - 0s - loss: 1.0802 - accuracy: 0.5310 - val_loss: 1.2032 - val_accuracy: 0.4593 - 14ms/epoch - 2ms/step
# Epoch 25/40
# 8/8 - 0s - loss: 1.0744 - accuracy: 0.5310 - val_loss: 1.2030 - val_accuracy: 0.4671 - 14ms/epoch - 2ms/step
# Epoch 26/40
# 8/8 - 0s - loss: 1.0696 - accuracy: 0.5336 - val_loss: 1.2030 - val_accuracy: 0.4690 - 14ms/epoch - 2ms/step
# Epoch 27/40
# 8/8 - 0s - loss: 1.0646 - accuracy: 0.5349 - val_loss: 1.2029 - val_accuracy: 0.4671 - 14ms/epoch - 2ms/step
# Epoch 28/40
# 8/8 - 0s - loss: 1.0594 - accuracy: 0.5401 - val_loss: 1.2033 - val_accuracy: 0.4690 - 14ms/epoch - 2ms/step
# Epoch 29/40
# 8/8 - 0s - loss: 1.0550 - accuracy: 0.5394 - val_loss: 1.2027 - val_accuracy: 0.4709 - 14ms/epoch - 2ms/step
# Epoch 30/40
# 8/8 - 0s - loss: 1.0499 - accuracy: 0.5472 - val_loss: 1.2034 - val_accuracy: 0.4690 - 13ms/epoch - 2ms/step
# Epoch 31/40
# 8/8 - 0s - loss: 1.0452 - accuracy: 0.5478 - val_loss: 1.2039 - val_accuracy: 0.4709 - 13ms/epoch - 2ms/step
# Epoch 32/40
# 8/8 - 0s - loss: 1.0410 - accuracy: 0.5543 - val_loss: 1.2048 - val_accuracy: 0.4671 - 13ms/epoch - 2ms/step
# Epoch 33/40
# 8/8 - 0s - loss: 1.0370 - accuracy: 0.5536 - val_loss: 1.2059 - val_accuracy: 0.4632 - 14ms/epoch - 2ms/step
# Epoch 34/40
# 8/8 - 0s - loss: 1.0315 - accuracy: 0.5523 - val_loss: 1.2069 - val_accuracy: 0.4671 - 13ms/epoch - 2ms/step
# Epoch 35/40
# 8/8 - 0s - loss: 1.0279 - accuracy: 0.5588 - val_loss: 1.2083 - val_accuracy: 0.4671 - 13ms/epoch - 2ms/step
# Epoch 36/40
# 8/8 - 0s - loss: 1.0231 - accuracy: 0.5607 - val_loss: 1.2083 - val_accuracy: 0.4651 - 14ms/epoch - 2ms/step
# Epoch 37/40
# 8/8 - 0s - loss: 1.0186 - accuracy: 0.5627 - val_loss: 1.2099 - val_accuracy: 0.4593 - 13ms/epoch - 2ms/step
# Epoch 38/40
# 8/8 - 0s - loss: 1.0148 - accuracy: 0.5614 - val_loss: 1.2118 - val_accuracy: 0.4632 - 13ms/epoch - 2ms/step
# Epoch 39/40
# 8/8 - 0s - loss: 1.0099 - accuracy: 0.5672 - val_loss: 1.2124 - val_accuracy: 0.4574 - 13ms/epoch - 2ms/step
# Epoch 40/40
# 8/8 - 0s - loss: 1.0056 - accuracy: 0.5678 - val_loss: 1.2145 - val_accuracy: 0.4535 - 13ms/epoch - 2ms/step
# CPU times: user 820 ms, sys: 146 ms, total: 966 ms
# Wall time: 799 ms

# %% [markdown]
# **Answer:**
# \
# The second and third neural network model couldn't perform as well as the first model (0.58 & 0.58 versus 0.93). Note that the first model has just 20 epoches instead of 40 but still performs better. It may be due to the selected 40 principal components failing to capture some important variance in the dataset. The missed variance in the components made the model difficult to predict accurately.

# %% [markdown]
# ## Discussion Questions

# %% [markdown]
# 1. In your own words, what is the difference between PCA and clustering?

# %% [markdown]
# ## Your Answer Here
#
# **Answer:**
# \

# %% [markdown]
# 2. Did you notice any advantages to combining PCA and clustering? If so, what do you think they were? If not, why do you think you didn't see any gains from this combination?

# %% [markdown]
# ## Your Answer Here
#
# **Answer:**
# \

# %% [markdown]
# 3. How can unsupervised techniques help with downstream supervised learning tasks when working with "big data?"

# %% [markdown]
# ## Your Answer Here
#
# **Answer:**
# \
