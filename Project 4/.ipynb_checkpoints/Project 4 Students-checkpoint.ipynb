# %% [markdown]
# # [Computational Social Science] Project 4: Unsupervised Learning
#
# **Enter your Name:** Jonah Lin
#
# *Semester:* Fall 2023

# %% [markdown]
# ## Data Description and Preprocessing
#
# For this project, you will explore data from the [National Health and Nutrition Examination Survey](https://www.kaggle.com/cdc/national-health-and-nutrition-examination-survey?select=questionnaire.csv). NHANES is a unique study that combines survey methodology with in-person medical examinations to create a dataset with demographic information, health indicators, and health outcomes.

# %% [markdown]
# We start by importing the data and doing some preliminary preprocessing for you. We import some libraries that will be helpful as well. 'SEQN' is the ID number for each respondent, and 'HSD010' will be our target outcome. [HSD010](https://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/HSQ_H.htm#HSD010) asks for the respondent's self reported health condition, which can range from "excellent" to "poor."

# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
sns.set_style("darkgrid")
from sklearn.model_selection import train_test_split

# %%
# Load nhanes data
nhanes = pd.read_csv('nhanes.csv')
# Get the ID numbers for each observation (seqn)
seqn = nhanes['SEQN']
# Get the target, "self-reported health condition," HSD010
hsd010 = nhanes['HSD010']
# Drop SEQN from the dataframe and then apply the standard scaler
nhanes = nhanes.drop(['SEQN', 'HSD010'], axis = 1)
nhanes_scaled = pd.DataFrame(StandardScaler().fit_transform(nhanes),
                             columns = nhanes.columns)
# Add the ID and target back in
nhanes_scaled['SEQN'] = seqn
nhanes_scaled['HSD010'] = hsd010
nhanes_scaled = nhanes_scaled.set_index('SEQN')
nhanes_scaled.head()
# Out:
#        DR1DRSTZ  DR1EXMER  DRABF    DRDINT   DR1DBIH    DR1DAY   DR1LANG  \
# SEQN
# 73568       0.0  2.034312    0.0  0.324834 -0.393906  1.085853 -0.194202
# 73576       0.0  0.261930    0.0 -3.078499  0.568251  0.634362 -0.194202
# 73579       0.0  0.728346    0.0  0.324834  1.530407 -1.623092 -0.194202
# 73581       0.0 -0.857470    0.0  0.324834  0.480782  1.085853 -0.194202
# 73584       0.0  0.495138    0.0  0.324834  0.305844 -1.623092 -0.194202
#
#        DR1MNRSP  DR1HELPD   DBQ095Z  ...    OHQ770    OHQ845   PAAQUEX  \
# SEQN                                 ...
# 73568 -0.057306  0.128246 -0.189513  ...  0.383802 -0.646584 -0.484200
# 73576 -0.057306  0.128246  0.080373  ...  0.383802 -1.539259 -0.484200
# 73579 -0.057306  0.128246 -0.189513  ...  0.383802 -1.539259  2.065262
# 73581 -0.057306  0.128246  0.080373  ...  0.383802 -0.646584 -0.484200
# 73584 -0.057306  0.128246  0.080373  ... -2.605509  0.246091  2.065262
#
#          SMQ860  SMQ870    SMQ872    SMQ874    SMQ878  SMAQUEX.x  HSD010
# SEQN
# 73568  1.125008     0.0 -2.081666  1.087115  1.463404   0.612440       1
# 73576  1.125008     0.0 -2.081666  1.087115 -0.683338  -1.632812       1
# 73579 -0.888883     0.0  0.480384 -0.919866 -0.683338  -1.632812       2
# 73581  1.125008     0.0  0.480384 -0.919866 -0.683338   0.612440       2
# 73584  1.125008     0.0  0.480384 -0.919866  1.463404  -1.632812       3
#
# [5 rows x 242 columns]

# %%
list(nhanes_scaled.columns).index('INDFMPIR'), list(nhanes_scaled.columns).index('BMXBMI')
# Out:
# (175, 76)

# %%
nhanes_scaled.shape
# Out:
# (2064, 242)

# %% [markdown]
# ## Plots

# %% [markdown]
# Let's take a look at the data. Below we visualize boxplots of family income to federal poverty line ratio ('INDFMPIR') and self-reported health condition. Notice how there are some clear patterns (the lower the ratio, the lower reported health condition), but it's not a perfect separation. We have 240+ features in our dataset, and we likely have several features in our dataset that highly correlate with our family income-poverty line ratio measure - PCA will help us simplify these.

# %%
# Create a binary version of hsd010 where 1-3 are "good" and 4-5 are "poor"
nhanes_scaled['HSD010_binary'] = hsd010_binary = nhanes_scaled['HSD010'].replace(
    [1, 2, 3, 4, 5], ['good', 'good', 'good', 'poor', 'poor']) 
# Recode the original hsd010 with the string labels
nhanes_scaled['HSD010'] = nhanes_scaled['HSD010'].replace(
    [1, 2, 3, 4, 5], ['excellent', 'very good', 'good', 'fair', 'poor'])
# Boxplot of hsd010
ax = sns.boxplot(x = 'HSD010', y = 'INDFMPIR', data = nhanes_scaled)
ax.set(xlabel = "Self Reported Health Condition",
      ylabel = "Family Income to Poverty Line Ratio")
ax.set_title("Boxplot of Family Income to Poverty Line Ratio by Self-Reported Health Status")
plt.show()

# %%
# Boxplot of hsd010_binary
ax = sns.boxplot(x = 'HSD010_binary', y = 'INDFMPIR', data = nhanes_scaled)
ax.set(xlabel = "Self Reported Health Condition",
      ylabel = "Family Income to Poverty Line Ratio")
ax.set_title("Boxplot of Family Income to Poverty Line Ratio by Binary Self-Reported Health Status")
plt.show()

# %% [markdown]
# Family income also is not necessarily well correlated with measured health outcomes. See below where we look at the relationship between Body Mass Index (BMI) and the family income-poverty line ratio, and shade points by self-reported health condition. It's hard to find a clear pattern - this is where clustering may come in handy.

# %%
ax = sns.scatterplot(x = "INDFMPIR", y = "BMXBMI", hue = "HSD010", palette = "tab10", data = nhanes_scaled)
ax.set(xlabel = "Income to Poverty Line Ratio",
      ylabel = "Body Mass Index")
ax.set_title("BMI v. Income-Poverty Ratio")
plt.show()

# %% [markdown]
# Before we move to working on unsupervised methods, we'll drop our target variables again:

# %%
nhanes_scaled = nhanes_scaled.drop(['HSD010', 'HSD010_binary'], axis = 1)

# nhanes_scaled['HSD010']

# %% [markdown]
# ## Principal Component Analysis

# %% [markdown]
# Conduct a Principal Component Analysis (PCA) of the nhanes data. The data has already been prepared for you, so you can work directly on nhanes_scaled. Be sure to do the following:
#
# - Choose the number of components and provide 1-2 sentences about your choice of the number of components.
# - Plot a barplot of the variation explained by each component. *Hint*: look at the attributes associated with your model.
# - Choose how many components you will use to fit a supervised learning model and provide 1-2 sentences to explain that choice.
# - Plot a 2D scatterplot of the first two components and provide 1-2 sentences analyzing the plot.

# %% [markdown]
# ### Train PCA and Discuss Number of Components

# %% [markdown]
# **Answer:**
# \
# Because the variance explained by each component is not clear at this point, I want to choose as many components as possible. But to plot all the chosen components, it shouldn't be larger than 100 or 200. So, I choose 80.

# %%
## Your Answer Here


X = StandardScaler().fit_transform(nhanes_scaled.values) 


pca_all = PCA() # notice we do not specify the number of components if we want to keep them all
principalComponents_nhanes = pca_all.fit_transform(X)

# %%
pca_80 = PCA(n_components=80) # notice we do not specify the number of components if we want to keep them all
PCA_80_components = pca_80.fit_transform(X)

# %%
sum(pca_80.explained_variance_ratio_) / sum(pca_all.explained_variance_ratio_)
# Out:
# 0.7766423157849095

# %% [markdown]
# ### Barplot of Components

# %%
## Your Answer Here

PC_values = np.arange(pca_80.n_components_) + 1

plt.bar(PC_values, pca_80.explained_variance_ratio_)
plt.xlabel('Principal Component')
plt.ylabel('Variance Explained')
plt.show()

# %% [markdown]
# ### How many components will you use to fit a supervised learning model?

# %% [markdown]
# **Answer:**
# \
# I choose 40 components for supervised learning later. As shown below, 40 components can explain almost 60% of all variance of the dataset.

# %%
## Your Answer Here


pca_40 = PCA(n_components=40) # notice we do not specify the number of components if we want to keep them all
PCA_40_components = pca_40.fit_transform(X)

sum(pca_40.explained_variance_ratio_)
# Out:
# 0.5953123794188977

# %%
PCA_40_components
# Out:
# array([[ 9.52780608, -0.81620821, -1.86714128, ...,  0.60660455,
#         -1.21982843,  0.66191923],
#        [-5.83834266, -3.69261549,  3.8053636 , ..., -2.27568412,
#          2.43636222, -1.39434615],
#        [-0.71945295, -2.57318933,  0.90794687, ...,  0.9584862 ,
#          0.37718007,  0.12588985],
#        ...,
#        [ 1.13025478, -0.97042547,  3.41526365, ...,  0.59673228,
#         -1.58604574,  0.12181872],
#        [ 7.14508892, -0.37676671,  1.75339163, ...,  0.86176011,
#          1.59727879,  1.00752206],
#        [ 0.05086952, -0.96731498, -4.44805442, ..., -0.39505414,
#          0.52982622,  0.47246657]])

# %%
PCA_40_components.shape
# Out:
# (2064, 40)

# %%
X.shape
# Out:
# (2064, 241)

# %% [markdown]
# ### 2D Scatterplot of the first two components

# %%
## Your Answer Here


pca_df = pd.DataFrame(data = PCA_40_components[:,:2], 
                      columns = ['principal component 1', 
                                 'principal component 2'])

# figure settings
plt.figure()
plt.figure(figsize=(10,10))
plt.xticks(fontsize=12)
plt.yticks(fontsize=14)
plt.xlabel('Principal Component - 1',fontsize=20)
plt.ylabel('Principal Component - 2',fontsize=20)
targets = [1, 2, 3, 4, 5]
colors = ['blue', 'orange', 'green', 'red', 'purple']

# loop over targets and colors to create scatterplot
for target, color in zip(targets,colors):
    indicesToKeep = hsd010 == target
    plt.scatter(pca_df.loc[indicesToKeep, 'principal component 1'], 
                pca_df.loc[indicesToKeep, 'principal component 2'], c = color, s = 50)

# show figure
plt.legend(targets,prop={'size': 15})
plt.show();

# %% [markdown]
# **Answer:**
# \
# From the figure, it is hard to tell a distribution pattern of the results (1=excellent, 2=very good...). It means the first two components do not catch enough variance of the data to show a pattern.

# %% [markdown]
# ## K-Means

# %% [markdown]
# - Choose a clustering algorithm and explain it in 1-2 sentences.
# - Cluster the nhanes data. Detail any choice you need to make with regards to number of clusters, and how you arrived at that choice. For instance, you might use the [elbow method](https://en.wikipedia.org/wiki/Elbow_method_(clustering)) if you choose k-means.
# - Plot your clusters on top of BMI v. Income Poverty Ratio Plot. Describe what you see in 1-2 sentences.
# - Retrain the clustering algorithm, but this time use your PCA results instead of the original dataframe. Plot the clusters on top of the 2D PCA scatterplot from the previous step. Describe your results in 1-2 sentences.

# %% [markdown]
# ### Choose a Clustering Algorithm

# %%
## Your Answer Here

# %% [markdown]
# **Answer:**
# \
# K-means.
# There is no obvious pattern of the distribution that makes any algorithms a better fit. With K-means, the number of clusters can be adjusted to find a (near) optimal cluster count that reduces the variance within clusters while not making too many clusters.

# %% [markdown]
# ### Cluster nhanes

# %%
## Your Answer Here

# %%
from sklearn.metrics import silhouette_samples, silhouette_score

range_n_clusters = list(range(2,20))
silho_score_list = []
distorsions = []

for n_clusters in range_n_clusters:

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, n_init="auto", random_state=10).fit(X)
    cluster_labels = clusterer.predict(X)
    
    distorsions.append(clusterer.inertia_)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(X, cluster_labels)
    silho_score_list.append(silhouette_avg)

fig, ax1 = plt.subplots()
line1, = ax1.plot(range_n_clusters, distorsions, 'go', label="elbow")
ax1.tick_params(axis='y', labelcolor='tab:green')

ax2 = ax1.twinx()
line2, = ax2.plot(range_n_clusters, silho_score_list, 'bx', label="silho_score")
ax2.tick_params(axis='y', labelcolor='tab:blue')

lines = [line1, line2]
labels = [line.get_label() for line in lines]

ax1.legend(lines, labels)

plt.show()

# %% [markdown]
# **Answer:**
# \
# The there is an elblow point at cluster_number=5, while the silhouette score remains relatively high. Plus, the number of clusters to be predicted for hsd010 is 5.

# %%
kmeans = KMeans(n_clusters=5, random_state=0).fit(X)
# Out:
# /Users/zhounanlin/anaconda3/envs/anlp/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %% [markdown]
# ### Plot your clusters on top of the BMI v. Income Poverty Ratio Plot

# %%
## Your Answer Here

# %%
X.shape
# Out:
# (2064, 241)

# %%
X[kmeans.labels_==0,:].shape
# Out:
# (150, 241)

# %%
X[kmeans.labels_==0,:][:2,:].shape
# Out:
# (2, 241)

# %%
# kmeans.cluster_centers_[:2,:]

# %%
X[kmeans.labels_==0,:].shape
# Out:
# (150, 241)

# %%
# X[kmeans.labels_==0,:][:, [175, 76]].T

# %%
# figure settings
fig = plt.figure()
ax1 = fig.add_subplot(111)

# plot
ax1.scatter(*(X[kmeans.labels_==0,:][:, [175, 76]].T), s=50, c='r', label='Cluster 0')
ax1.scatter(*(X[kmeans.labels_==1,:][:, [175, 76]].T), s=50, c='b', label='Cluster 1')
ax1.scatter(*(X[kmeans.labels_==2,:][:, [175, 76]].T), s=50, c='g', label='Cluster 2')
ax1.scatter(*(X[kmeans.labels_==3,:][:, [175, 76]].T), s=50, c='orange', label='Cluster 3')
ax1.scatter(*(X[kmeans.labels_==4,:][:, [175, 76]].T), s=50, c='purple', label='Cluster 4')
ax1.scatter(*kmeans.cluster_centers_[:, [175, 76]].T, s=50, marker='+', c='black', label='cluster centers')
plt.legend(loc='upper left')
plt.xlabel('feature0')
plt.ylabel('feature1')
plt.show()

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# **Answer:**
# \
# The resulting clusters do show some patterns. The blue cluster seems to be centered around the bottom right, while the purple cluster seems to be centered around bottom left. However, it not clear at this point which cluster corresponds to which HSD010 (self reported health condition).

# %% [markdown]
# ### Retrain the clustering algorithm on PCA components and plot clusters on your 2D scatter

# %%
## Your Answer Here

# %%
kmeans_2 = KMeans(n_clusters=5, random_state=0).fit(PCA_40_components)
# Out:
# /Users/zhounanlin/anaconda3/envs/anlp/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
PCA_40_components[kmeans_2.labels_==4,:].shape
# Out:
# (148, 40)

# %%
kmeans_2.cluster_centers_[:, :2].T
# Out:
# array([[ 7.45966306, -0.20221004, -2.21010936, -2.65569299, -4.23396565],
#        [ 0.65310408, -2.02871971,  1.06781627, -2.61774273, 12.18948569]])

# %%
# figure settings
fig2 = plt.figure()
ax2 = fig2.add_subplot(111)

# plot
ax2.scatter(*(PCA_40_components[kmeans_2.labels_==0,:][:, :2].T), s=50, c='r', label='Cluster 0')
ax2.scatter(*(PCA_40_components[kmeans_2.labels_==1,:][:, :2].T), s=50, c='b', label='Cluster 1')
ax2.scatter(*(PCA_40_components[kmeans_2.labels_==2,:][:, :2].T), s=50, c='g', label='Cluster 2')
ax2.scatter(*(PCA_40_components[kmeans_2.labels_==3,:][:, :2].T), s=50, c='orange', label='Cluster 3')
ax2.scatter(*(PCA_40_components[kmeans_2.labels_==4,:][:, :2].T), s=50, c='purple', label='Cluster 4')
ax2.scatter(*kmeans_2.cluster_centers_[:, :2].T, s=50, marker='+', c='black', label='cluster centers')
plt.legend(loc='upper left')
plt.xlabel('feature0')
plt.ylabel('feature1')
plt.show()

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# **Answer:**
# \
# A clear distribution pattern is visible in the figure above.
# \
# However, comparing this figure to the figure in "2D Scatterplot of the first two components" of PCA analysis section, the five clusters achieved from the kmeans clustering of PCA components is not very accurate.

# %% [markdown]
# ## Neural Network

# %% [markdown]
# Now we are ready to predict! Do the following:
#
# - Choose either HSD010 or HSD010\_binary as your target outcome.
# - Train a neural network using the original features. Much of the code to train a basic neural net has been set up for you, but you will need to fill in a couple of missing pieces.
# - Train a neural network using only your PCA components as features.
# - Train a neural network using your PCA components and the predicted class membership from your clustering algorithm as features.
# - Compare and contrast how well each algorithm did. Which featurization technique would you pick and why?

# %% [markdown]
# Below we provide a template for training a neural network. Use this template for training on the original features, on the PCA components, and the PCA components + the predicted classes from your clusters.

# %% [markdown]
# ### Neural Network on Original Features

# %%
## Your Answer Here

# %%
# partition data
# -----------
y = hsd010 # either hsd010 or hsd010_binary, may need to convert to numeric if it isn't already 
X_nn = X # drop out any columns that aren't features

X_train, X_test, y_train, y_test = train_test_split(X_nn, 
                                                    y, 
                                                    test_size = .25, 
                                                    random_state = 10)


# keras.utils.to_categorical
# starts index from 0
# so, reduce y_train and y_test by 1

y_train -= 1
y_test -= 1

# %%
# load libraries
# -----------
import keras
from keras.utils import to_categorical

num_classes = 5
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
num_classes = y_test.shape[1]

# %%
num_classes
# Out:
# 5

# %%
X_train.shape
# Out:
# (1548, 241)

# %%
# %%time

# create neural network model
# -----------
model = Sequential()

model.add(Dense(X_train.shape[1], input_dim=X_train.shape[1], kernel_initializer='normal', activation='relu'))

model.add(Dense(num_classes, kernel_initializer='normal', activation='softmax'))

## Add any additional layers you wish here

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=20, batch_size=200, verbose=2)
# Out:
# Epoch 1/20
# 8/8 - 0s - loss: 1.4730 - accuracy: 0.3359 - val_loss: 1.3552 - val_accuracy: 0.3953 - 197ms/epoch - 25ms/step
# Epoch 2/20
# 8/8 - 0s - loss: 1.2241 - accuracy: 0.4929 - val_loss: 1.2948 - val_accuracy: 0.4167 - 17ms/epoch - 2ms/step
# Epoch 3/20
# 8/8 - 0s - loss: 1.1203 - accuracy: 0.5342 - val_loss: 1.2632 - val_accuracy: 0.4341 - 16ms/epoch - 2ms/step
# Epoch 4/20
# 8/8 - 0s - loss: 1.0450 - accuracy: 0.5678 - val_loss: 1.2491 - val_accuracy: 0.4496 - 17ms/epoch - 2ms/step
# Epoch 5/20
# 8/8 - 0s - loss: 0.9820 - accuracy: 0.6124 - val_loss: 1.2413 - val_accuracy: 0.4457 - 19ms/epoch - 2ms/step
# Epoch 6/20
# 8/8 - 0s - loss: 0.9240 - accuracy: 0.6324 - val_loss: 1.2347 - val_accuracy: 0.4380 - 21ms/epoch - 3ms/step
# Epoch 7/20
# 8/8 - 0s - loss: 0.8694 - accuracy: 0.6628 - val_loss: 1.2322 - val_accuracy: 0.4535 - 19ms/epoch - 2ms/step
# Epoch 8/20
# 8/8 - 0s - loss: 0.8207 - accuracy: 0.7009 - val_loss: 1.2384 - val_accuracy: 0.4438 - 18ms/epoch - 2ms/step
# Epoch 9/20
# 8/8 - 0s - loss: 0.7724 - accuracy: 0.7306 - val_loss: 1.2416 - val_accuracy: 0.4477 - 18ms/epoch - 2ms/step
# Epoch 10/20
# 8/8 - 0s - loss: 0.7252 - accuracy: 0.7584 - val_loss: 1.2484 - val_accuracy: 0.4380 - 17ms/epoch - 2ms/step
# Epoch 11/20
# 8/8 - 0s - loss: 0.6808 - accuracy: 0.7745 - val_loss: 1.2642 - val_accuracy: 0.4380 - 16ms/epoch - 2ms/step
# Epoch 12/20
# 8/8 - 0s - loss: 0.6386 - accuracy: 0.8094 - val_loss: 1.2754 - val_accuracy: 0.4535 - 16ms/epoch - 2ms/step
# Epoch 13/20
# 8/8 - 0s - loss: 0.5984 - accuracy: 0.8340 - val_loss: 1.2884 - val_accuracy: 0.4477 - 16ms/epoch - 2ms/step
# Epoch 14/20
# 8/8 - 0s - loss: 0.5584 - accuracy: 0.8488 - val_loss: 1.3020 - val_accuracy: 0.4419 - 16ms/epoch - 2ms/step
# Epoch 15/20
# 8/8 - 0s - loss: 0.5217 - accuracy: 0.8643 - val_loss: 1.3235 - val_accuracy: 0.4477 - 16ms/epoch - 2ms/step
# Epoch 16/20
# 8/8 - 0s - loss: 0.4860 - accuracy: 0.8721 - val_loss: 1.3447 - val_accuracy: 0.4457 - 16ms/epoch - 2ms/step
# Epoch 17/20
# 8/8 - 0s - loss: 0.4519 - accuracy: 0.8889 - val_loss: 1.3614 - val_accuracy: 0.4496 - 16ms/epoch - 2ms/step
# Epoch 18/20
# 8/8 - 0s - loss: 0.4189 - accuracy: 0.9089 - val_loss: 1.3784 - val_accuracy: 0.4477 - 16ms/epoch - 2ms/step
# Epoch 19/20
# 8/8 - 0s - loss: 0.3877 - accuracy: 0.9199 - val_loss: 1.3960 - val_accuracy: 0.4593 - 16ms/epoch - 2ms/step
# Epoch 20/20
# 8/8 - 0s - loss: 0.3612 - accuracy: 0.9380 - val_loss: 1.4207 - val_accuracy: 0.4496 - 16ms/epoch - 2ms/step
# CPU times: user 727 ms, sys: 136 ms, total: 863 ms
# Wall time: 631 ms

# %% [markdown]
# ### Neural Network on Principal Components

# %%
## Your Answer Here

# %%
# partition data
# -----------
y = hsd010 # either hsd010 or hsd010_binary, may need to convert to numeric if it isn't already 
X_nn = PCA_40_components # drop out any columns that aren't features

X_train, X_test, y_train, y_test = train_test_split(X_nn, 
                                                    y, 
                                                    test_size = .25, 
                                                    random_state = 10)


# keras.utils.to_categorical
# starts index from 0
# so, reduce y_train and y_test by 1

y_train -= 1
y_test -= 1

# %%
# load libraries
# -----------
import keras
from keras.utils import to_categorical

num_classes = 5
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
num_classes = y_test.shape[1]

# %%
num_classes
# Out:
# 5

# %%
X_train.shape
# Out:
# (1548, 40)

# %%
# %%time

# create neural network model
# -----------
model = Sequential()

model.add(Dense(X_train.shape[1], input_dim=X_train.shape[1], kernel_initializer='normal', activation='relu'))

model.add(Dense(num_classes, kernel_initializer='normal', activation='softmax'))

## Add any additional layers you wish here

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=20, batch_size=200, verbose=2)
# Out:
# Epoch 1/20
# 8/8 - 0s - loss: 1.5975 - accuracy: 0.2836 - val_loss: 1.5525 - val_accuracy: 0.3857 - 148ms/epoch - 18ms/step
# Epoch 2/20
# 8/8 - 0s - loss: 1.5398 - accuracy: 0.4037 - val_loss: 1.5051 - val_accuracy: 0.4399 - 13ms/epoch - 2ms/step
# Epoch 3/20
# 8/8 - 0s - loss: 1.4888 - accuracy: 0.4432 - val_loss: 1.4631 - val_accuracy: 0.4457 - 13ms/epoch - 2ms/step
# Epoch 4/20
# 8/8 - 0s - loss: 1.4435 - accuracy: 0.4599 - val_loss: 1.4256 - val_accuracy: 0.4438 - 13ms/epoch - 2ms/step
# Epoch 5/20
# 8/8 - 0s - loss: 1.4020 - accuracy: 0.4716 - val_loss: 1.3930 - val_accuracy: 0.4360 - 14ms/epoch - 2ms/step
# Epoch 6/20
# 8/8 - 0s - loss: 1.3641 - accuracy: 0.4722 - val_loss: 1.3650 - val_accuracy: 0.4380 - 13ms/epoch - 2ms/step
# Epoch 7/20
# 8/8 - 0s - loss: 1.3310 - accuracy: 0.4774 - val_loss: 1.3409 - val_accuracy: 0.4341 - 14ms/epoch - 2ms/step
# Epoch 8/20
# 8/8 - 0s - loss: 1.3012 - accuracy: 0.4793 - val_loss: 1.3203 - val_accuracy: 0.4380 - 14ms/epoch - 2ms/step
# Epoch 9/20
# 8/8 - 0s - loss: 1.2753 - accuracy: 0.4806 - val_loss: 1.3024 - val_accuracy: 0.4341 - 16ms/epoch - 2ms/step
# Epoch 10/20
# 8/8 - 0s - loss: 1.2520 - accuracy: 0.4806 - val_loss: 1.2878 - val_accuracy: 0.4322 - 14ms/epoch - 2ms/step
# Epoch 11/20
# 8/8 - 0s - loss: 1.2317 - accuracy: 0.4871 - val_loss: 1.2753 - val_accuracy: 0.4264 - 13ms/epoch - 2ms/step
# Epoch 12/20
# 8/8 - 0s - loss: 1.2132 - accuracy: 0.4916 - val_loss: 1.2649 - val_accuracy: 0.4302 - 13ms/epoch - 2ms/step
# Epoch 13/20
# 8/8 - 0s - loss: 1.1972 - accuracy: 0.4955 - val_loss: 1.2563 - val_accuracy: 0.4225 - 12ms/epoch - 1ms/step
# Epoch 14/20
# 8/8 - 0s - loss: 1.1827 - accuracy: 0.5013 - val_loss: 1.2490 - val_accuracy: 0.4264 - 12ms/epoch - 1ms/step
# Epoch 15/20
# 8/8 - 0s - loss: 1.1694 - accuracy: 0.5026 - val_loss: 1.2429 - val_accuracy: 0.4360 - 14ms/epoch - 2ms/step
# Epoch 16/20
# 8/8 - 0s - loss: 1.1574 - accuracy: 0.5110 - val_loss: 1.2386 - val_accuracy: 0.4322 - 13ms/epoch - 2ms/step
# Epoch 17/20
# 8/8 - 0s - loss: 1.1463 - accuracy: 0.5136 - val_loss: 1.2339 - val_accuracy: 0.4322 - 13ms/epoch - 2ms/step
# Epoch 18/20
# 8/8 - 0s - loss: 1.1364 - accuracy: 0.5161 - val_loss: 1.2306 - val_accuracy: 0.4322 - 12ms/epoch - 2ms/step
# Epoch 19/20
# 8/8 - 0s - loss: 1.1266 - accuracy: 0.5168 - val_loss: 1.2279 - val_accuracy: 0.4360 - 12ms/epoch - 2ms/step
# Epoch 20/20
# 8/8 - 0s - loss: 1.1178 - accuracy: 0.5226 - val_loss: 1.2257 - val_accuracy: 0.4360 - 13ms/epoch - 2ms/step
# CPU times: user 464 ms, sys: 68.8 ms, total: 533 ms
# Wall time: 447 ms

# %% [markdown]
# ### Neural Network on Principal Components + Cluster Membership

# %%
## Your Answer Here

# %%
# np.hstack((PCA_40_components, kmeans_2.labels_.reshape(-1, 1)))

# %%
# partition data
# -----------
y = hsd010 # either hsd010 or hsd010_binary, may need to convert to numeric if it isn't already 
X_nn = np.hstack((PCA_40_components, kmeans_2.labels_.reshape(-1, 1))) # drop out any columns that aren't features

X_train, X_test, y_train, y_test = train_test_split(X_nn, 
                                                    y, 
                                                    test_size = .25, 
                                                    random_state = 10)


# keras.utils.to_categorical
# starts index from 0
# so, reduce y_train and y_test by 1

y_train -= 1
y_test -= 1

# %%
# load libraries
# -----------
import keras
from keras.utils import to_categorical

num_classes = 5
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
num_classes = y_test.shape[1]

# %%
num_classes
# Out:
# 5

# %%
X_train.shape
# Out:
# (1548, 41)

# %%
# %%time

# create neural network model
# -----------
model = Sequential()

model.add(Dense(X_train.shape[1], input_dim=X_train.shape[1], kernel_initializer='normal', activation='relu'))

model.add(Dense(num_classes, kernel_initializer='normal', activation='softmax'))

## Add any additional layers you wish here

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=20, batch_size=200, verbose=2)
# Out:
# Epoch 1/20
# 8/8 - 0s - loss: 1.5860 - accuracy: 0.2842 - val_loss: 1.5473 - val_accuracy: 0.3760 - 146ms/epoch - 18ms/step
# Epoch 2/20
# 8/8 - 0s - loss: 1.5253 - accuracy: 0.4057 - val_loss: 1.4943 - val_accuracy: 0.4205 - 14ms/epoch - 2ms/step
# Epoch 3/20
# 8/8 - 0s - loss: 1.4720 - accuracy: 0.4367 - val_loss: 1.4488 - val_accuracy: 0.4380 - 12ms/epoch - 2ms/step
# Epoch 4/20
# 8/8 - 0s - loss: 1.4242 - accuracy: 0.4548 - val_loss: 1.4089 - val_accuracy: 0.4380 - 13ms/epoch - 2ms/step
# Epoch 5/20
# 8/8 - 0s - loss: 1.3816 - accuracy: 0.4612 - val_loss: 1.3750 - val_accuracy: 0.4302 - 14ms/epoch - 2ms/step
# Epoch 6/20
# 8/8 - 0s - loss: 1.3432 - accuracy: 0.4716 - val_loss: 1.3468 - val_accuracy: 0.4380 - 14ms/epoch - 2ms/step
# Epoch 7/20
# 8/8 - 0s - loss: 1.3099 - accuracy: 0.4793 - val_loss: 1.3239 - val_accuracy: 0.4535 - 15ms/epoch - 2ms/step
# Epoch 8/20
# 8/8 - 0s - loss: 1.2817 - accuracy: 0.4897 - val_loss: 1.3049 - val_accuracy: 0.4399 - 15ms/epoch - 2ms/step
# Epoch 9/20
# 8/8 - 0s - loss: 1.2559 - accuracy: 0.5000 - val_loss: 1.2897 - val_accuracy: 0.4438 - 13ms/epoch - 2ms/step
# Epoch 10/20
# 8/8 - 0s - loss: 1.2343 - accuracy: 0.5019 - val_loss: 1.2770 - val_accuracy: 0.4516 - 13ms/epoch - 2ms/step
# Epoch 11/20
# 8/8 - 0s - loss: 1.2149 - accuracy: 0.5045 - val_loss: 1.2653 - val_accuracy: 0.4593 - 12ms/epoch - 2ms/step
# Epoch 12/20
# 8/8 - 0s - loss: 1.1980 - accuracy: 0.5058 - val_loss: 1.2558 - val_accuracy: 0.4593 - 12ms/epoch - 2ms/step
# Epoch 13/20
# 8/8 - 0s - loss: 1.1821 - accuracy: 0.5058 - val_loss: 1.2484 - val_accuracy: 0.4554 - 13ms/epoch - 2ms/step
# Epoch 14/20
# 8/8 - 0s - loss: 1.1686 - accuracy: 0.5065 - val_loss: 1.2425 - val_accuracy: 0.4690 - 13ms/epoch - 2ms/step
# Epoch 15/20
# 8/8 - 0s - loss: 1.1562 - accuracy: 0.5103 - val_loss: 1.2376 - val_accuracy: 0.4651 - 13ms/epoch - 2ms/step
# Epoch 16/20
# 8/8 - 0s - loss: 1.1455 - accuracy: 0.5110 - val_loss: 1.2340 - val_accuracy: 0.4671 - 12ms/epoch - 1ms/step
# Epoch 17/20
# 8/8 - 0s - loss: 1.1348 - accuracy: 0.5181 - val_loss: 1.2307 - val_accuracy: 0.4612 - 12ms/epoch - 2ms/step
# Epoch 18/20
# 8/8 - 0s - loss: 1.1254 - accuracy: 0.5194 - val_loss: 1.2280 - val_accuracy: 0.4612 - 12ms/epoch - 2ms/step
# Epoch 19/20
# 8/8 - 0s - loss: 1.1167 - accuracy: 0.5213 - val_loss: 1.2270 - val_accuracy: 0.4593 - 13ms/epoch - 2ms/step
# Epoch 20/20
# 8/8 - 0s - loss: 1.1086 - accuracy: 0.5245 - val_loss: 1.2255 - val_accuracy: 0.4671 - 12ms/epoch - 1ms/step
# CPU times: user 459 ms, sys: 75.2 ms, total: 534 ms
# Wall time: 439 ms

# %% [markdown]
# **Answer:**
# \
# The second and third neural network model couldn't perform as well as the first model (0.58 & 0.58 versus 0.93). Note that the first model has just 20 epoches instead of 40 but still performs better. It may be due to the selected 40 principal components failing to capture some important variance in the dataset. The missed variance in the components made the model difficult to predict accurately.

# %% [markdown]
# ## Discussion Questions

# %% [markdown]
# 1. In your own words, what is the difference between PCA and clustering?

# %% [markdown]
# ## Your Answer Here
#
# **Answer:**
# \
# PCA is used to capture the correlation between variables and merge variables to reduce dimensions. PCA does not indicate anything about the prediction result. Clustering is to group the datapoints by their spatial distribution with a selected grouping algorithm. The clustering can be based on the original variables (original dimensions) or the PCA component dimensions (reduced dimensions). The clusters output by a clustering algorithm can directly help further prediction or even be taken as prediction result.

# %% [markdown]
# 2. Did you notice any advantages to combining PCA and clustering? If so, what do you think they were? If not, why do you think you didn't see any gains from this combination?

# %% [markdown]
# ## Your Answer Here
#
# **Answer:**
# \
# Yes. Combining PCA and clustering and help reduce the computation cost (or time), because there are fewer dimensions after applying PCA.

# %% [markdown]
# 3. How can unsupervised techniques help with downstream supervised learning tasks when working with "big data?"

# %% [markdown]
# ## Your Answer Here
#
# **Answer:**
# \
# Unsupervised techniques like PCA and clustering can help to find some patterns within the dataset. These patterns can reduce dimension and generate additional information for supervised learning later.
